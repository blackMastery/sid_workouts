# %%
# !pip install mediapipe

# %%
import cv2
import numpy as np
import mediapipe as mp
import time

# %%
def calculate_angle(a,b,c):
    first = np.array(a)
    mid = np.array(b)
    end = np.array(c)
    radians = np.arctan2(end[1] - mid[1], end[0] - mid[0]) - np.arctan2(first[1] - mid[1], first[0] - mid[0])
    angle = np.abs(radians * 180.0/np.pi)
    if angle > 180.0:
        angle 360 - angle
    
    return angle

# %%
class WorkoutDetector():
    def __init__(self,  static_image_mode=False, model_complexity=1, smooth_landmarks=True,min_detection_confidence=0.5,
    min_tracking_confidence=0.5):
        
        self.static_image_mode = static_image_mode
        self.model_complexity = model_complexity
        self.smooth_landmarks = smooth_landmarks
        self.min_detection_confidence = min_detection_confidence 
        self.min_tracking_confidence = min_tracking_confidence
        
        self.mpDraw =  mp.solutions.drawing_utils
        self.mpPose =  mp.solutions.pose
        
        self.pose =  self.mpPose.Pose(
            self.static_image_mode,
            self.model_complexity,
            self.smooth_landmarks,
            self.min_detection_confidence,
            self.min_tracking_confidence,
        )
        
        
    def calculate_angle(self, image,land_marks, draw=True):
        pos_a, pos_b, pos_c = land_marks
        lm1, lm1_x , lm1_y = self.lmList[pos_a]
        lm2, lm2_x , lm2_y = self.lmList[pos_b]
        lm3, lm3_x , lm3_y = self.lmList[pos_c]
        radians = np.arctan2(lm3_y - lm2_y, lm3_x - lm2_x) - np.arctan2(lm1_y - lm2_y, lm1_x - lm2_x)
        angle = np.abs(radians * 180.0/np.pi)
        
        if angle > 180.0:
            angle = 360 - angle
        

#         print(angle)    
        if(draw):
#             cv2.putText(image, str(int(angle)), (70,50), cv2.FONT_HERSHEY_PLAIN, 3, (255, 0,0), 3)
            cv2.line(image, (lm1_x, lm1_y), (lm2_x, lm2_y), (255,255,255),3)
            cv2.line(image, (lm2_x, lm2_y), (lm3_x, lm3_y), (255,255,255), 3)
            
            cv2.circle(image, (lm1_x, lm1_y), 15, (23,0,250), cv2.FILLED)
            cv2.circle(image, (lm2_x, lm2_y), 10, (10,0,250), cv2.FILLED)
            cv2.circle(image, (lm3_x, lm3_y), 5, (30,0,250), cv2.FILLED)
        return int(angle)

            
    
    
    
    
    def get_distance_btw_landmarks(self, image, lm_a, lm_b, draw=True):
        
        lm1, lm1_x , lm1_y = self.lmList[lm_a]
        lm2, lm2_x , lm2_y = self.lmList[lm_b]
        
        if draw:
            cv2.line(image, (lm1_x, lm1_y), (lm2_x, lm2_y), (255,255,255),3)
            cv2.circle(image, (lm1_x, lm1_y), 15, (23,0,250), cv2.FILLED)
            cv2.circle(image, (lm2_x, lm2_y), 15, (23,0,250), cv2.FILLED)
            
        return lm1_x - lm2_x
            
            
            
        
        
        
        
    def draw_angle(self, image, land_marks):
        pos_a, pos_b, pos_c = land_marks
        
        lm1, lm1_x , lm1_y = self.lmList[pos_a]
        lm2, lm2_x , lm2_y = self.lmList[pos_b]
        lm3, lm3_x , lm3_y = self.lmList[pos_c]
        
        cv2.line(image, (lm1_x, lm1_y), (lm2_x, lm2_y), (255,255,255),3)
        cv2.line(image, (lm2_x, lm2_y), (lm3_x, lm3_y), (255,255,255), 3)

        cv2.circle(image, (lm1_x, lm1_y), 15, (23,0,250), cv2.FILLED)
        cv2.circle(image, (lm2_x, lm2_y), 10, (10,0,250), cv2.FILLED)
        cv2.circle(image, (lm3_x, lm3_y), 5, (30,0,250), cv2.FILLED)
        
        
    def getPosition(self, img, draw=True, world=False):
        self.lmList = []
        
        if self.results.pose_landmarks:
        
         # Plot pose world landmarks.
            if world:
                self.mpDraw.plot_landmarks(
            self.results.pose_world_landmarks, self.mpPose.POSE_CONNECTIONS)
            
            for id, lm in enumerate(self.results.pose_landmarks.landmark):
                h, w, c = img.shape
#                 print(id, lm)
                # getting the pixel values
                cx, cy = int(lm.x * w), int(lm.y * h)
                self.lmList.append([id, cx, cy])
                if draw:
                    cv2.circle(image, (cx, cy), 5, (255,0,0), cv2.FILLED)
        return self.lmList
        
    def findPose(self, img, draw=True):

        img =  cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        # MAKE DETECTIONS
        self.results = self.pose.process(img)
        
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        if self.results.pose_landmarks:
            if draw:
                self.mpDraw.draw_landmarks(img, self.results.pose_landmarks, self.mpPose.POSE_CONNECTIONS )
        return img

# %%
detector = WorkoutDetector()

while True:
    image = cv2.imread(pushup_start)
    image = detector.findPose(image, draw=False)
    lmList = detector.getPosition(image, draw=False)
    
    if len(lmList) > 1:
        detector.calculate_angle(image,15,23,31)

    cv2.imshow('Image', image)
    
    if cv2.waitKey(10) & 0xff == ord('q'):
        break
cv2.destroyAllWindows()

# cv2.destroyAllWindows()

# %% [markdown]
# # Squat workout Pipeline

# %%
squatVid = 'squat/squatv4.mp4'
squatStartImg = 'squat/start.png'
squatMidImg = 'squat/mid.png'

# %%
detector = WorkoutDetector()

while True:
    image = cv2.imread(squatMidImg)
    image = detector.findPose(image, draw=False)
    lmList = detector.getPosition(image, draw=False)
    
    if len(lmList) > 1:
        detector.calculate_angle(image,23,25,27)

    cv2.imshow('Image', image)
    
    if cv2.waitKey(10) & 0xff == ord('q'):
        break
cv2.destroyAllWindows()

# %%
detector = WorkoutDetector()

cap = cv2.VideoCapture(squatVid)


def squat():
    pTime = 0
    count = 0
    stage =None

    while True:
        success, img = cap.read()

        image = detector.findPose(img, draw=False)
        lmList = detector.getPosition(img, draw=False)

        if len(lmList) > 1:
            angle = int(detector.calculate_angle(image,23,25,27, draw=False))
    #         detector.draw_angle(image,23,25,27)
            ankle_width = detector.get_distance_btw_landmarks(image,27, 28 )
            knee_width = detector.get_distance_btw_landmarks(image,25, 26 )



            mycount = "ankle: {}, knee: {} stage: {} ".format(int(ankle_width), knee_width, stage)

            if knee_width > ankle_width:
                if angle:
                    if angle >= 170  and stage == 'down':
                        stage = 'up'
                        count +=1
                    if angle <= 90:
                        stage = 'down'
        cv2.putText(image, mycount, (70,50), cv2.FONT_HERSHEY_PLAIN, 3, (255, 0,0), 3)
        cv2.imshow('Image', image)

        if cv2.waitKey(10) & 0xff == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
squat()

# %% [markdown]
# # Bicycle Crunches
#
# ## Bicycle crunche Stages
# 1. START_LEFT_LEG_BENTUP_RIGHT_LEG_STRAIGHT
# 2. START_RIGHT_LEG_BENTUP_LEFT_LEG_STRAIGHT
# 3. END_LEFT_STRAIGHT_RIGHT_LEG_BENTUP
# 4. END_RIGHT_STRAIGHT_LEFT_LEG_STRAIGHT

# %%
bicycle_crunche_path = 'bicycyle_crunches/'

end_left_leg_down = 'crunche_end_left_leg_down.png'
end_right_leg_down = 'crunche_end_right_leg_down.png'

start_left_leg_up = 'crunche_start_left_leg_up.png'
start_right_leg_up = 'crunche_start_right_leg_up.png'

# bicycle_crunche_path+start_left_leg_up

# %%
def bent(angle, angle_check):
    return angle < angle_check




detector = WorkoutDetector()

while True:
    image = cv2.imread(bicycle_crunche_path+start_right_leg_up)
    image = detector.findPose(image, draw=False)
    lmList = detector.getPosition(image, draw=False)
#     le_el = detector.calculate_angle(image,11,13,15)
#     ri_el = detector.calculate_angle(image,12,14,16)
    
#     le_kne = detector.calculate_angle(image,23,25,27)
#     ri_kne = detector.calculate_angle(image,24,26,28)
#     detector.get_distance_btw_landmarks(image,13,26)
    detector.get_distance_btw_landmarks(image,11,23)
    
    
    
#     print(ri_el, bent(le_el, 45), bent(le_kne,45), ri_kne)
#     angles = " {} {} {}  {}".format(int(ri_el), le_el, le_kne, ri_kne)
#     cv2.putText(image, angles, (70,50), cv2.FONT_HERSHEY_PLAIN, 3, (255, 0,0), 3)
    
    
    
    
    
#     if len(lmList) > 1:
#         detector.calculate_angle(image,23,25,27)

    cv2.imshow('Image', image)
    
    if cv2.waitKey(10) & 0xff == ord('q'):
        break
cv2.destroyAllWindows()

# %%
detector = WorkoutDetector()

cap = cv2.VideoCapture(bicycle_crunche_path+start_left_leg_up)

while True:
    success, img = cap.read()

    image = detector.findPose(img, draw=False)
    lmList = detector.getPosition(img)


    cv2.imshow('Image', image)

    if cv2.waitKey(10) & 0xff == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-4-6f9621a6c490> in <module>
#       6     success, img = cap.read()
#       7
# ----> 8     image = detector.findPose(img, draw=False)
#       9     lmList = detector.getPosition(img)
#      10
#
# <ipython-input-2-a2ddaa5efa33> in findPose(self, img, draw)
#      96     def findPose(self, img, draw=True):
#      97
# ---> 98         img =  cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#      99         # MAKE DETECTIONS
#     100         self.results = self.pose.process(img)
#
# error: OpenCV(4.5.2) /tmp/pip-req-build-vrhoqk3o/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %% [markdown]
# ## In out Jumps

# %%
jumps_path =  'in_out_jumps/'

In_and_Out_Jump_mp4 = 'In_and_Out_Jump.mp4'


in__out_jump_start = 'in__out_jump_start.png'


close_leg_squat_down = 'in_out_jump_close_leg_squat_down.png'

jump_legs_straight = 'in_out_jump_jump_legs_straight.png'

legs_wide_squat_start = 'in_out_jumps_legs_wide_squat_start.png'

leg_wide_squat_down = 'in_out_jump_leg_wide_squat_down.png'

# %%
leg_leg_lms = [23,25,27]
leg_right_lms = [24,26,28]

left_arm_lms = [11,13,15]
right_arm_lms = [12,14,16]


def bent(angle, angle_check=45):
    return angle < angle_check


def not_bent(angle, angle_check=150):
    return angle > angle_check and angle < 187

# %%
detector = WorkoutDetector()

distance_of_ankles_start = 0

while True:
    image = cv2.imread(jumps_path+jump_legs_straight)
    image = detector.findPose(image, draw=False)
    lmList = detector.getPosition(image)
    le_el = detector.calculate_angle(image,leg_leg_lms)
    ri_el = detector.calculate_angle(image,leg_right_lms)
    
    arm_left_angle = detector.calculate_angle(image,left_arm_lms)
    arm_right_angle = detector.calculate_angle(image,right_arm_lms)
    
# #     print(le_el, ri_el)
#     if bent(arm_left_angle) and bent(arm_left_angle):
        
#         if not_bent(le_el) and not_bent(ri_el):
#             distance_of_ankles_start = detector.get_distance_btw_landmarks(image,27, 28)
# #             print("up start position", distance_of_ankles)
# #             if detector.get_distance_btw_landmarks(image,27, 28) > distance_of_ankles_start:
# #                 print("jump", distance_of_ankles)
#         if not not_bent(le_el) and not not_bent(ri_el):
#             print("down Position")

    
#     le_kne = detector.calculate_angle(image,23,25,27)
#     ri_kne = detector.calculate_angle(image,24,26,28)
#     detector.get_distance_btw_landmarks(image,11,23)
    


    cv2.imshow('Image', image)
    
    if cv2.waitKey(10) & 0xff == ord('q'):
        break
cv2.destroyAllWindows()

# %%
detector = WorkoutDetector()

cap = cv2.VideoCapture(jumps_path+In_and_Out_Jump_mp4)

distance_of_ankles_start = 0
stage = None

while True:
        success, img = cap.read()

        image = detector.findPose(img, draw=False)
        lmList = detector.getPosition(img)
        
        left_leg = detector.calculate_angle(image,leg_leg_lms)
        right_leg = detector.calculate_angle(image,leg_right_lms)
    
        arm_left_angle = detector.calculate_angle(image,left_arm_lms)
        arm_right_angle = detector.calculate_angle(image,right_arm_lms)
        
        if bent(arm_left_angle) and bent(arm_left_angle):
            distance_of_ankles = detector.get_distance_btw_landmarks(image,27, 28)
            print(stage, left_leg, left_leg, 'distance_of_ankles', distance_of_ankles )

            if not_bent(left_leg) and not_bent(right_leg):
                stage = 'start_position'
                print(stage, left_leg, left_leg, 'distance_of_ankles', distance_of_ankles )
                
                
            if bent(left_leg, 99) and bent(right_leg, 99) and stage == 'start_position':
                stage = 'down_position'
                print(stage, left_leg, left_leg, 'distance_of_ankles', distance_of_ankles )
                
                
                
        

        cv2.imshow('Image', image)

        if cv2.waitKey(10) & 0xff == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()
# Out:
# None 169 169 distance_of_ankles 56
# start_position 169 169 distance_of_ankles 56
# start_position 168 168 distance_of_ankles 56
# start_position 168 168 distance_of_ankles 56
# start_position 167 167 distance_of_ankles 57
# start_position 167 167 distance_of_ankles 57
# start_position 165 165 distance_of_ankles 57
# start_position 165 165 distance_of_ankles 57
# start_position 156 156 distance_of_ankles 60
# start_position 156 156 distance_of_ankles 60
# start_position 152 152 distance_of_ankles 59
# start_position 152 152 distance_of_ankles 59
# start_position 149 149 distance_of_ankles 58
# start_position 147 147 distance_of_ankles 57
# start_position 140 140 distance_of_ankles 57
# start_position 136 136 distance_of_ankles 57
# start_position 136 136 distance_of_ankles 57
# start_position 134 134 distance_of_ankles 57
# start_position 133 133 distance_of_ankles 57
# start_position 128 128 distance_of_ankles 56
# start_position 121 121 distance_of_ankles 55
# start_position 121 121 distance_of_ankles 55
# start_position 123 123 distance_of_ankles 54
# start_position 128 128 distance_of_ankles 54
# start_position 137 137 distance_of_ankles 54
# start_position 159 159 distance_of_ankles 254
# start_position 150 150 distance_of_ankles 254
# start_position 145 145 distance_of_ankles 258
# start_position 139 139 distance_of_ankles 257
# start_position 136 136 distance_of_ankles 256
# start_position 124 124 distance_of_ankles 256
# start_position 119 119 distance_of_ankles 257
# start_position 114 114 distance_of_ankles 257
# start_position 111 111 distance_of_ankles 256
# start_position 106 106 distance_of_ankles 256
# start_position 107 107 distance_of_ankles 257
# start_position 109 109 distance_of_ankles 257
# start_position 112 112 distance_of_ankles 257
# start_position 121 121 distance_of_ankles 257
# start_position 122 122 distance_of_ankles 257
# start_position 131 131 distance_of_ankles 257
# start_position 138 138 distance_of_ankles 258
# start_position 148 148 distance_of_ankles 257
# start_position 153 153 distance_of_ankles 257
# start_position 178 178 distance_of_ankles 73
# start_position 178 178 distance_of_ankles 73
# start_position 179 179 distance_of_ankles 62
# start_position 179 179 distance_of_ankles 62
# start_position 176 176 distance_of_ankles 59
# start_position 176 176 distance_of_ankles 59
# start_position 171 171 distance_of_ankles 63
# start_position 171 171 distance_of_ankles 63
# start_position 165 165 distance_of_ankles 64
# start_position 165 165 distance_of_ankles 64
# start_position 161 161 distance_of_ankles 60
# start_position 156 156 distance_of_ankles 61
# start_position 149 149 distance_of_ankles 61
# start_position 145 145 distance_of_ankles 61
# start_position 143 143 distance_of_ankles 62
# start_position 142 142 distance_of_ankles 61
# start_position 135 135 distance_of_ankles 61
# start_position 129 129 distance_of_ankles 60
# start_position 125 125 distance_of_ankles 60
# start_position 124 124 distance_of_ankles 61
# start_position 129 129 distance_of_ankles 60
# start_position 132 132 distance_of_ankles 59
# start_position 127 127 distance_of_ankles 58
# start_position 130 130 distance_of_ankles 58
# start_position 138 138 distance_of_ankles 58
# start_position 144 144 distance_of_ankles 60
# start_position 149 149 distance_of_ankles 60
# start_position 153 153 distance_of_ankles 61
# start_position 154 154 distance_of_ankles 277
# start_position 141 141 distance_of_ankles 280
# start_position 136 136 distance_of_ankles 279
# start_position 128 128 distance_of_ankles 278
# start_position 123 123 distance_of_ankles 277
# start_position 120 120 distance_of_ankles 279
# start_position 116 116 distance_of_ankles 280
# start_position 109 109 distance_of_ankles 280
# start_position 104 104 distance_of_ankles 281
# start_position 102 102 distance_of_ankles 280
# start_position 100 100 distance_of_ankles 281
# start_position 99 99 distance_of_ankles 281
# start_position 99 99 distance_of_ankles 281
# start_position 101 101 distance_of_ankles 281
# start_position 106 106 distance_of_ankles 281
# start_position 112 112 distance_of_ankles 281
# start_position 126 126 distance_of_ankles 281
# start_position 134 134 distance_of_ankles 281
# start_position 138 138 distance_of_ankles 281
# start_position 147 147 distance_of_ankles 281
# start_position 151 151 distance_of_ankles 281
# start_position 154 154 distance_of_ankles 280
# start_position 160 160 distance_of_ankles 280
# start_position 174 174 distance_of_ankles 282
# start_position 178 178 distance_of_ankles 283
# start_position 178 178 distance_of_ankles 283
# start_position 175 175 distance_of_ankles 271
# start_position 175 175 distance_of_ankles 271
# start_position 174 174 distance_of_ankles 245
# start_position 174 174 distance_of_ankles 245
# start_position 176 176 distance_of_ankles 173
# start_position 176 176 distance_of_ankles 173
# start_position 178 178 distance_of_ankles 139
# start_position 178 178 distance_of_ankles 139
